# %%
import pandas as pd
import numpy as np
import csv

# %%
# !pip install -U -q PyDrive

from pydrive.auth import GoogleAuth

from pydrive.drive import GoogleDrive

from google.colab import auth

from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()

gauth = GoogleAuth()

gauth.credentials = GoogleCredentials.get_application_default()

drive = GoogleDrive(gauth)

# %%
fileDownloaded = drive.CreateFile({'id' :'17N9Q-R4XJtFVyvzSszmNdeYm-Njrybob'})

# %%
fileDownloaded.GetContentFile('observations-255685.csv')

# %%
import pandas as pd

df = pd.read_csv('observations-255685.csv')

df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (13,24) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                id      observed_on_string observed_on  \
# 0           19007  October 31, 2008 11:01  2008-10-31
# 1           19010  October 28, 2008 11:59  2008-10-28
# 2           19011  October 27, 2008 11:15  2008-10-27
# 3           25640               7/14/2011  2011-07-14
# 4           25641               7/14/2011  2011-07-14
# ...           ...                     ...         ...
# 157525  131230628     2022-08-17 13:05:09  2022-08-17
# 157526  131233678      2022/08/14 1:34 PM  2022-08-14
# 157527  131234282     2022-07-20 14:19:44  2022-07-20
# 157528  131234287     2022-08-17 13:39:11  2022-08-17
# 157529  131235178     2022-08-13 11:16:24  2022-08-13
#
#                time_observed_at                   time_zone  user_id  \
# 0       2008-10-31 18:01:00 UTC  Pacific Time (US & Canada)      873
# 1       2008-10-28 18:59:00 UTC  Pacific Time (US & Canada)      873
# 2       2008-10-27 18:15:00 UTC  Pacific Time (US & Canada)      873
# 3                           NaN                     Arizona      516
# 4                           NaN                     Arizona      516
# ...                         ...                         ...      ...
# 157525  2022-08-17 18:05:09 UTC                 Mexico City  1900036
# 157526  2022-08-14 18:34:00 UTC                 Mexico City  6035541
# 157527  2022-07-20 19:19:44 UTC                 Mexico City  3483283
# 157528  2022-08-17 18:39:11 UTC                   Monterrey   749743
# 157529  2022-08-13 16:16:24 UTC                 Mexico City  1472048
#
#             user_login               created_at               updated_at  \
# 0             tapbirds  2011-05-30 07:57:16 UTC  2022-04-13 14:04:22 UTC
# 1             tapbirds  2011-05-30 08:01:47 UTC  2022-07-13 21:56:20 UTC
# 2             tapbirds  2011-05-30 08:02:57 UTC  2018-04-24 21:16:49 UTC
# 3                  msr  2011-07-21 01:37:20 UTC  2017-07-20 00:23:25 UTC
# 4                  msr  2011-07-21 01:51:56 UTC  2019-01-08 19:58:14 UTC
# ...                ...                      ...                      ...
# 157525      salvador58  2022-08-17 18:14:29 UTC  2022-08-17 18:14:35 UTC
# 157526     eduardo1179  2022-08-17 18:36:35 UTC  2022-08-17 18:36:35 UTC
# 157527  valeriaugaldee  2022-08-17 18:40:55 UTC  2022-08-17 18:41:31 UTC
# 157528      eberchavez  2022-08-17 18:40:58 UTC  2022-08-17 18:59:56 UTC
# 157529      martharomo  2022-08-17 18:47:43 UTC  2022-08-17 18:47:50 UTC
#
#        quality_grade  ... taxon_superorder_name taxon_order_name  \
# 0           research  ...                   NaN         Squamata
# 1           research  ...                   NaN       Crocodylia
# 2           research  ...                   NaN         Squamata
# 3           research  ...                   NaN         Squamata
# 4           research  ...                   NaN         Squamata
# ...              ...  ...                   ...              ...
# 157525      needs_id  ...                   NaN         Squamata
# 157526      needs_id  ...                   NaN         Squamata
# 157527      needs_id  ...                   NaN         Squamata
# 157528      needs_id  ...                   NaN         Squamata
# 157529      needs_id  ...                   NaN         Squamata
#
#        taxon_suborder_name taxon_superfamily_name taxon_family_name  \
# 0                   Sauria                    NaN           Teiidae
# 1                      NaN                    NaN      Crocodylidae
# 2                Serpentes                    NaN        Colubridae
# 3                   Sauria                    NaN         Iguanidae
# 4                   Sauria                    NaN         Iguanidae
# ...                    ...                    ...               ...
# 157525           Serpentes                    NaN        Colubridae
# 157526           Serpentes                    NaN         Viperidae
# 157527              Sauria                    NaN   Phrynosomatidae
# 157528           Serpentes                    NaN        Colubridae
# 157529              Sauria                    NaN   Phrynosomatidae
#
#        taxon_subfamily_name  taxon_supertribe_name  taxon_genus_name  \
# 0                   Teiinae                    NaN      Aspidoscelis
# 1                       NaN                    NaN        Crocodylus
# 2                Natricinae                    NaN        Thamnophis
# 3                       NaN                    NaN       Dipsosaurus
# 4                       NaN                    NaN        Ctenosaura
# ...                     ...                    ...               ...
# 157525           Colubrinae                    NaN      Lampropeltis
# 157526           Crotalinae                    NaN          Crotalus
# 157527         Sceloporinae                    NaN        Sceloporus
# 157528           Colubrinae                    NaN         Salvadora
# 157529         Sceloporinae                    NaN        Sceloporus
#
#         taxon_genushybrid_name     taxon_species_name
# 0                          NaN  Aspidoscelis cozumela
# 1                          NaN      Crocodylus acutus
# 2                          NaN    Thamnophis proximus
# 3                          NaN   Dipsosaurus dorsalis
# 4                          NaN   Ctenosaura hemilopha
# ...                        ...                    ...
# 157525                     NaN  Lampropeltis polyzona
# 157526                     NaN   Crotalus triseriatus
# 157527                     NaN                    NaN
# 157528                     NaN    Salvadora grahamiae
# 157529                     NaN    Sceloporus magister
#
# [157530 rows x 53 columns]
